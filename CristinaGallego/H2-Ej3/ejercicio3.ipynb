# %% [markdown]
# Ejercicio 3
# ==
#  DIAGRAMA RELACIONAL DE UNA COMPAÑIA

# %%
from IPython.display import Image

Image("./ej3.JPG")

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///ej3.db
# Out:
# 'Connected: None@ej3.db'

# %%
# %%sql
# DROP TABLE IF EXISTS departamento;
# CREATE TABLE departamento(
#     id INT,
#     Nombre VARCHAR(30),
#     Presupuesto FLOAT,
#     nif_emp VARCHAR(10) NOT NULL,
#     PRIMARY KEY (id),
#     FOREIGN KEY(nif_emp) REFERENCES empleados(nif)
# );
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS empleados;
# CREATE TABLE empleados(
#     nif VARCHAR(10),
#     salario FLOAT,
#     Telefono INT,
#     PRIMARY KEY(nif)
# );
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS tienen_hijos;
# CREATE TABLE tienen_hijos(
#     nombre VARCHAR(20),
#     edad INT,
#     nif_padre VARCHAR(10) NOT NULL,
#     PRIMARY KEY (nombre, dni),
#     FOREIGN KEY (nif_padre) REFERENCES empleados (nif)ON DELETE CASCADE
# );
# Out:
# Done.
# (sqlite3.OperationalError) no such column: dni [SQL: 'CREATE TABLE tienen_hijos(\n    nombre VARCHAR(20),\n    edad INT,\n    nif_padre VARCHAR(10) NOT NULL,\n    PRIMARY KEY (nombre, dni),\n    FOREIGN KEY (nif_padre) REFERENCES empleados (nif)ON DELETE CASCADE\n);']

# %%
# %%sql
# DROP TABLE IF EXISTS trabajan_en;
# CREATE TABLE trabajan_en(
#     nif VARCHAR(10),
#     id INT,
#     FOREIGN KEY (nif) REFERENCES empleados(nif),
#     FOREIGN KEY (id) REFERENCES departamentos(id)
# );
# Out:
# Done.
# Done.
# []

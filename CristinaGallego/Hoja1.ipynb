# %% [markdown]
# EJERCICIOS HOJA 1 - DISEÑO DIAGRAMA ER
# ==
# Dos ejercicios - varios apartados

# %% [markdown]
# Ejercicio 1.1 : Diseño de diagramas ER para profesores de una Universidad
# - a . Imagen
# - b . Se expresa como una busqueda para qué modelos es experto. Podemos realizarlo mediante una tripleta entre:
#     Técnicos - Avión - Modelo que mantengan la relacion "Pasa Prueba".

# %%
from IPython.display import Image

Image("./ej1-1.JPG")

# %% [markdown]
# Ejercicio 1.2 : Diseño del diagrama ER de una Universidad

# %%
from IPython.display import Image

Image("./ej1-2.JPG")

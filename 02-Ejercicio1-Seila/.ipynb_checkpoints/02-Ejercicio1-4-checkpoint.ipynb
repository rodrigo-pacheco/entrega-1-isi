# %%
from IPython.display import Image
Image("./02-Ejercicio1-4.png")

# %%
# %load_ext sql
# %sql sqlite:///02-ejercicio1-4.db
# Out:
# 'Connected: None@02-ejercicio1-4.db'

# %%
# %%sql create table asignatura(num int,
#                               primary key(num));
# Out:
# Done.
# []

# %%
# %%sql create table profesor(dni varchar(10),
#                             num_asig int not null,
#                             cuatrimestre int,
#                             primary key(dni, cuatrimestre)
#                             foreign key (num_asig) references asignatura(num));
# Out:
# Done.
# []

# %%
# %sql select * from profesor
# Out:
# Done.
# []

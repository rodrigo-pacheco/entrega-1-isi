# %%
from IPython.display import Image
Image("./02-Ejercicio1-3.png")

# %%
# %load_ext sql
# %sql sqlite:///02-ejercicio1-3.db
# Out:
# 'Connected: None@02-ejercicio1-3.db'

# %%
# %%sql create table profesor(dni varchar(10),
#                            primary key(dni));
# Out:
# Done.
# []

# %%
# %%sql create table asignatura(num int,
#                               primary key(num));
# Out:
# Done.
# []

# %%
# %%sql create table enseña(dni varchar(10) not null,
#                          num_asig int,
#                          cuatrimestre int,
#                          primary key(dni, num_asig),
#                          foreign key(dni) references profesores(dni),
#                          foreign key(num_asig) references asignatura(num));
# Out:
# Done.
# []
